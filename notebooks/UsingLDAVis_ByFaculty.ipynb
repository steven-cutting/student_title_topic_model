# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pickle

# %%
from gensim import corpora
from gensim import models

import pyLDAvis.gensim

# %% [markdown]
# ---

# %% [markdown]
# # Loading Files

# %% [markdown]
# ## Loading Corpus and Dictionary

# %%
DICTIONARY = corpora.Dictionary.load("./student_titles_dict.dict")
# BOW_CORPUS = corpora.MmCorpus("./student_titles_bow_corpus.mm")

# %%
with open("./corpus_by_faculty.pickle") as f:
    FCORPUS = pickle.load(f)

# %% [markdown]
# ## Loading Models

# %%
TFIDF_MODEL = models.TfidfModel.load("./student_topic.tfidf")
LDA_MODEL = models.LdaModel.load("./student_topic.lda")

# %% [markdown]
# ---

# %% [markdown]
# # Visualizing LDA Model

# %% [markdown]
# ### Accountancy

# %%
# %time vis_data = pyLDAvis.gensim.prepare(LDA_MODEL, FCORPUS['School of Accountancy'], DICTIONARY)
# Out:
# CPU times: user 8.94 s, sys: 565 ms, total: 9.51 s
# Wall time: 37.1 s

# %%
pyLDAvis.display(vis_data)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el999847548081443124841669"></div>
# <script type="text/javascript">
#
# ...

# %% [markdown]
# ### Social Sciences

# %%
# %time vis_data2 = pyLDAvis.gensim.prepare(LDA_MODEL, FCORPUS['School of Social Sciences'], DICTIONARY)
# Out:
# CPU times: user 15.4 s, sys: 471 ms, total: 15.9 s
# Wall time: 41.5 s

# %%
pyLDAvis.display(vis_data2)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el999846803582247966327939"></div>
# <script type="text/javascript">
#
# ...

# %% [markdown]
# ### Economics

# %%
# %time vis_data3 = pyLDAvis.gensim.prepare(LDA_MODEL, FCORPUS['School of Economics'], DICTIONARY)
# Out:
# CPU times: user 9.34 s, sys: 333 ms, total: 9.68 s
# Wall time: 29.6 s

# %%
pyLDAvis.display(vis_data3)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el999847612781605150417323"></div>
# <script type="text/javascript">
#
# ...

# %% [markdown]
# ### Law

# %%
# %time vis_data4 = pyLDAvis.gensim.prepare(LDA_MODEL, FCORPUS['School of Law'], DICTIONARY)
# Out:
# CPU times: user 8.95 s, sys: 316 ms, total: 9.27 s
# Wall time: 28.9 s

# %%
pyLDAvis.display(vis_data4)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el99984759462224701039388"></div>
# <script type="text/javascript">
#
# ...

# %% [markdown]
# ### Business

# %%
# %time vis_data5 = pyLDAvis.gensim.prepare(LDA_MODEL, FCORPUS['Lee Kong Chian School of Business'], DICTIONARY)
# Out:
# CPU times: user 19.7 s, sys: 389 ms, total: 20.1 s
# Wall time: 39.6 s

# %%
pyLDAvis.display(vis_data5)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el999846824153128697088527"></div>
# <script type="text/javascript">
#
# ...

# %% [markdown]
# ### Information Systems

# %%
# %time vis_data6 = pyLDAvis.gensim.prepare(LDA_MODEL, FCORPUS['School of Information Systems'], DICTIONARY)
# Out:
# CPU times: user 8.68 s, sys: 318 ms, total: 9 s
# Wall time: 28.6 s

# %%
pyLDAvis.display(vis_data6)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el999847594642727124526095"></div>
# <script type="text/javascript">
#
# ...

# %% [markdown]
# ### Others

# %%
# %time vis_data7 = pyLDAvis.gensim.prepare(LDA_MODEL, FCORPUS['Others'], DICTIONARY)
# Out:
# CPU times: user 6.95 s, sys: 440 ms, total: 7.39 s
# Wall time: 33.1 s

# %%
pyLDAvis.display(vis_data7)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el999846824123687635774646"></div>
# <script type="text/javascript">
#
# ...
